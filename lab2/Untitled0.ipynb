# %%
import numpy as np
import pandas as pd

dates = pd.date_range('20130101', periods=6)
dates
df2 = pd.DataFrame({ 'A' : 1,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D' : np.array([3] * 4, dtype='int32'),
                    'E' : 'foo'})
df2
# Out:
#    A          B  C  D    E
# 0  1 2013-01-02  1  3  foo
# 1  1 2013-01-02  1  3  foo
# 2  1 2013-01-02  1  3  foo
# 3  1 2013-01-02  1  3  foo
#
# [4 rows x 5 columns]

# %%
df2 = pd.DataFrame(np.random.randn(10,5), columns=list('ABCDE'))
df2
# Out:
#           A         B         C         D         E
# 0  1.438693  0.772877 -1.168418  0.649237 -0.440665
# 1 -1.569149 -1.909733 -1.475543  0.702958 -0.756972
# 2 -0.018907  0.893343 -0.961006  0.710857  0.090498
# 3 -1.484582  0.568474 -1.131684  0.487779 -0.562904
# 4  1.656590 -0.628990 -0.140615  0.191828 -0.540167
# 5  0.401748  0.280381 -1.664174 -0.977247 -1.130468
# 6  0.570615 -0.264516 -1.432307  1.614740 -0.389292
# 7  0.804711 -0.826207  0.409616  0.619868 -0.553595
# 8 -1.879796  0.669619 -0.246103  0.412222  0.534055
# 9  0.250660  0.100234 -2.013796 -1.405095  0.249971
#
# [10 rows x 5 columns]

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
frame = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])
print frame
# Out:
#    pop   state  year
# a  1.5    Ohio  2000
# b  1.7    Ohio  2001
# c  3.6    Ohio  2002
# d  2.4  Nevada  2001
# e  2.9  Nevada  2002
#
# [5 rows x 3 columns]

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four', 'five'])
frame2
frame2['debt'] = 16.5
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
#
# [5 rows x 4 columns]

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
#
# [5 rows x 4 columns]

# %%
pop = {'Nevada': {2001 : 2.4, 2002: 2.9},
       'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
frame3 = pd.DataFrame(pop)
print frame3
pd.DataFrame(pop, index=[2000, 2001, 2002, 2003])
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6
#
# [3 rows x 2 columns]
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN
#
# [4 rows x 2 columns]

# %%
pdata = {'Ohio': frame3['Ohio'][:-1],
         'Nevada': frame3['Nevada'][:2]}
pdata
frame3.index.name = 'year'; frame3.columns.name = 'state'
frame3.values
frame2.values
# Out:
# array([[2000L, 'Ohio', 1.5, nan],
#        [2001L, 'Ohio', 1.7, -1.2],
#        [2002L, 'Ohio', 3.6, nan],
#        [2001L, 'Nevada', 2.4, -1.5],
#        [2002L, 'Nevada', 2.9, -1.7]], dtype=object)
